# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
snapshot = torch.load('../train_results/lm_head_learnable/last_snapshot.tar', map_location='cpu')
history = snapshot['history']
train_loss = history['train_loss']
train_perp = history['train_perplexity']

# %%
plt.plot(train_loss)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training loss')
plt.grid()
plt.show()

# %%
import numpy as np

# %%
# plt.plot(train_perp[25:])
plt.plot(np.arange(len(train_perp[25:])) + 25, train_perp[25:])
plt.xlabel('Epoch')
plt.ylabel('Perplexity')
plt.title('Training perplexity')
plt.grid()
plt.show()
